# %%
import torch

tmp = torch.load('./birdclef-2023/checkpoints/cnn_ft/test/checkpoint_epoch_19.pth')

# %%
tmp
# Out:
# {'epoch': 19,
#  'loss': 6.238655016182713,
#  'f1_score': 0.15493603469097988,
# ...
